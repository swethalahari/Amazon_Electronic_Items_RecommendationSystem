# %%
import pandas as pd
import numpy as np

# %%
cols = ['UserID','ItemID','Rating','Time']
ds = pd.read_csv('ratings_Electronics.csv',names = cols)

# %%
ds.shape
# Out:
# (7824482, 4)

# %%
ds.head()
# Out:
#            UserID      ItemID  Rating        Time
# 0   AKM1MP6P0OYPR  0132793040     5.0  1365811200
# 1  A2CX7LUOHB2NDG  0321732944     5.0  1341100800
# 2  A2NWSAGRHCP8N5  0439886341     1.0  1367193600
# 3  A2WNBOD3WNDNKT  0439886341     3.0  1374451200
# 4  A1GI0U4ZRJA8WN  0439886341     1.0  1334707200

# %%
ds.UserID.unique().shape[0]
# Out:
# 4201696

# %%
ds.drop(['Time'],axis=1,inplace =True)

# %%
ds.ItemID.unique().shape[0]
# Out:
# 476002

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
Unique_Items_Count = ds.ItemID.value_counts().reset_index()
#print(Unique_Items_Count)

# %%
# As the dataset is too huge, from the above we know that there are items that are reated only once., 
# we can think of removing tose items

# %%
User_count_df = ds.groupby(['UserID', 'ItemID']).size().groupby('UserID').size()
print('# Users: %d' % len(User_count_df))
User_with_enough_ratings_df = User_count_df[User_count_df >= 2].reset_index()[['UserID']]
print('# Users Who has rated atleast twice: %d' % len(User_with_enough_ratings_df))
User_with_enough_ratings_df.head()
# Out:
# # Users: 4201696
# # Users Who has rated atleast twice: 1319864
#                   UserID
# 0  A000063614T1OE0BUSKUT
# 1   A0001528BGUBOEVR6T5U
# 2  A00018041RRVMCICCAP79
# 3  A000187635I595IAVSQLH
# 4  A00033481VZEEGYXEN32T

# %%
Item_count_df = ds.groupby(['UserID', 'ItemID' ,'Rating']).size().groupby('ItemID').size()
print('# items: %d' % len(Item_count_df))
Item_with_enough_ratings_df = Item_count_df[Item_count_df >= 2].reset_index()[['ItemID']]
print('# Items with atleast 2 purchases: %d' % len(Item_with_enough_ratings_df))
# Out:
# # items: 476002
# # Items with atleast 2 purchases: 296264

# %%
Item_with_enough_ratings_df.head()
# Out:
#        ItemID
# 0  0439886341
# 1  0511189877
# 2  0528881469
# 3  059400232X
# 4  0594012015

# %%
density_Ratio = float(len(User_with_enough_ratings_df) / len(User_count_df))
density_Ratio
# Out:
# 0.31412648606657884

# %%
# The data has density of 31%

# %%
User_count_df.head()
# Out:
# UserID
# A00000262KYZUE4J55XGL    1
# A000063614T1OE0BUSKUT    2
# A00009182QVLSWIGHLS1B    1
# A00009661LC9LQPGKJ24G    1
# A00010809P09NUU6ZP6H     1
# dtype: int64

# %%
ds.Rating.value_counts()
# Out:
# 5.0    4347541
# 4.0    1485781
# 1.0     901765
# 3.0     633073
# 2.0     456322
# Name: Rating, dtype: int64

# %%
ds.isna().sum()
# Out:
# UserID    0
# ItemID    0
# Rating    0
# dtype: int64

# %%
# of unique Users / Interactions
print(float(ds.UserID.unique().shape[0]/ds.shape[0]))
# Out:
# 0.5369935032120976

# %%
## Of the total number of rating data we have, we are having the 53.7% unique users data. 
## Rest 46 % are the Same Users for various Items rating data.

# %%
## Make the data Sparse by selectin those users who have atleast rated twice
#df = ds.merge(User_with_enough_ratings_df,how = "inner", on = 'UserID')
df = ds.head(200000)

# %%
df.shape
# Out:
# (200000, 3)

# %%
df.columns
# Out:
# Index(['UserID', 'ItemID', 'Rating'], dtype='object')

# %%
item_grouped = df.groupby(['ItemID']).agg({'Rating':'count'}).reset_index()
item_grp_sum = item_grouped.Rating.sum()
item_grouped['Percentage'] = (item_grouped['Rating'].div(item_grp_sum))*100
item_grouped.head(5)
# Out:
#        ItemID  Rating  Percentage
# 0  0132793040       1      0.0005
# 1  0321732944       1      0.0005
# 2  0439886341       3      0.0015
# 3  0511189877       6      0.0030
# 4  0528881469      27      0.0135

# %%
## Sort items based on Ratings in descending order, coz, more the number of Ratings, more frequent / used / good / popular the item is
item_grouped.sort_values(['Rating','ItemID'],ascending=[0,1])
# Out:
#            ItemID  Rating  Percentage
# 5130   B00004ZCJE    2547      1.2735
# 2111   B00001P4ZH    2075      1.0375
# 9388   B000065BP9    1714      0.8570
# 3268   B00004T8R2    1692      0.8460
# 2248   B00001WRSJ    1586      0.7930
# 9390   B000065BPB    1304      0.6520
# 7345   B00005N6KG    1296      0.6480
# 8104   B00005T3G0    1287      0.6435
# 7088   B00005LEN4    1107      0.5535
# 10953  B00006B7DA    1106      0.5530
# 38     0972683275    1051      0.5255
# 8773   B000062VUO    1042      0.5210
# 2963   B00004SABB    1030      0.5150
# 6442   B00005ATMB    1015      0.5075
# 2969   B00004SB92    1006      0.5030
# 9733   B000067O5G    1003      0.5015
# 9814   B000067RC4     999      0.4995
# 9224   B0000645RH     975      0.4875
# 7441   B00005NIMJ     884      0.4420
# 9921   B000067RT6     883      0.4415
# 3413   B00004THCZ     820      0.4100
# 4665   B00004Z5M1     815      0.4075
# 6433   B00005ARK3     795      0.3975
# 5073   B00004ZC8Y     720      0.3600
# 7265   B00005ML7Q     687      0.3435
# 4063   B00004WCGF     680      0.3400
# 9556   B000066E6Y     680      0.3400
# 12396  B00006HYPV     676      0.3380
# 8027   B00005T39Y     606      0.3030
# 6445   B00005ATMI     597      0.2985
# ...           ...     ...         ...
# 13007  B00006JHP5       1      0.0005
# 13010  B00006JHUI       1      0.0005
# 13016  B00006JHVB       1      0.0005
# 13050  B00006JI73       1      0.0005
# 13051  B00006JI7M       1      0.0005
# 13052  B00006JI7R       1      0.0005
# 13058  B00006JI9L       1      0.0005
# 13059  B00006JI9R       1      0.0005
# 13060  B00006JILA       1      0.0005
# 13062  B00006JILV       1      0.0005
# 13069  B00006JK0M       1      0.0005
# 13071  B00006JK16       1      0.0005
# 13076  B00006JK64       1      0.0005
# 13077  B00006JK65       1      0.0005
# 13078  B00006JK66       1      0.0005
# 13081  B00006JK6B       1      0.0005
# 13083  B00006JK6K       1      0.0005
# 13085  B00006JK6N       1      0.0005
# 13100  B00006JLPX       1      0.0005
# 13102  B00006JLWT       1      0.0005
# 13103  B00006JM0F       1      0.0005
# 13111  B00006JM5S       1      0.0005
# 13112  B00006JM5T       1      0.0005
# 13113  B00006JM60       1      0.0005
# 13114  B00006JM63       1      0.0005
# 13116  B00006JM6I       1      0.0005
# 13119  B00006JM6O       1      0.0005
# 13120  B00006JM6P       1      0.0005
# 13122  B00006JM6S       1      0.0005
# 13125  B00006JM71       1      0.0005
#
# [13131 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
train_df, test_df = train_test_split(df,test_size=0.30,random_state=42)

# %%
import time
import Recommenders as Recommenders
import Evaluation as Evaluation

# %%
# Build Popularity based model
PM = Recommenders.popularity_recommender_py()

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 140000 entries, 21269 to 121958
# Data columns (total 3 columns):
# UserID    140000 non-null object
# ItemID    140000 non-null object
# Rating    140000 non-null float64
# dtypes: float64(1), object(2)
# memory usage: 4.3+ MB

# %%
def create_popularity_recommendation(train_data, user_id, item_id):
    #Get a count of user_ids for each unique song as recommendation score
    train_data_grouped = train_data.groupby([item_id]).agg({user_id: 'count'}).reset_index()
    train_data_grouped.rename(columns = {user_id: 'score'},inplace=True)
    
    #Sort the songs based upon recommendation score
    train_data_sort = train_data_grouped.sort_values(['score', item_id], ascending = [0,1])
    
    #Generate a recommendation rank based upon score
    train_data_sort['Rank'] = train_data_sort['score'].rank(ascending=0, method='first')
        
    #Get the top 10 recommendations
    popularity_recommendations = train_data_sort.head(20)
    return popularity_recommendations

# %%
recommendations = create_popularity_recommendation(train_df,'UserID','ItemID')

# %%
recommendations
# Out:
#           ItemID  score  Rank
# 4572  B00004ZCJE   1777   1.0
# 1803  B00001P4ZH   1471   2.0
# 8458  B000065BP9   1206   3.0
# 2871  B00004T8R2   1183   4.0
# 1930  B00001WRSJ   1077   5.0
# 7285  B00005T3G0    931   6.0
# 8460  B000065BPB    887   7.0
# 6590  B00005N6KG    863   8.0
# 6343  B00005LEN4    795   9.0
# 9865  B00006B7DA    769  10.0
# 7894  B000062VUO    747  11.0
# 2585  B00004SABB    733  12.0
# 35    0972683275    726  13.0
# 5756  B00005ATMB    708  14.0
# 8771  B000067O5G    704  15.0
# 2591  B00004SB92    703  16.0
# 8844  B000067RC4    692  17.0
# 8310  B0000645RH    667  18.0
# 6677  B00005NIMJ    628  19.0
# 8936  B000067RT6    601  20.0

# %%
uid = ds['UserID'][35575]
uid
# Out:
# 'A3FTRN2V98QBCP'

# %%
def recommend_item(user_id):    
        user_recommendations = recommendations
        
        #Add user_id column for which the recommendations are being generated
        user_recommendations['userId'] = user_id
    
        #Bring user_id column to the front
        cols = user_recommendations.columns.tolist()
        cols = cols[-1:] + cols[:-1]
        user_recommendations = user_recommendations[cols]
        
        return (user_recommendations)

# %%
recommended_items = recommend_item(uid)

# %%
recommended_items
# Out:
#               userId      ItemID  score  Rank
# 4572  A3FTRN2V98QBCP  B00004ZCJE   1777   1.0
# 1803  A3FTRN2V98QBCP  B00001P4ZH   1471   2.0
# 8458  A3FTRN2V98QBCP  B000065BP9   1206   3.0
# 2871  A3FTRN2V98QBCP  B00004T8R2   1183   4.0
# 1930  A3FTRN2V98QBCP  B00001WRSJ   1077   5.0
# 7285  A3FTRN2V98QBCP  B00005T3G0    931   6.0
# 8460  A3FTRN2V98QBCP  B000065BPB    887   7.0
# 6590  A3FTRN2V98QBCP  B00005N6KG    863   8.0
# 6343  A3FTRN2V98QBCP  B00005LEN4    795   9.0
# 9865  A3FTRN2V98QBCP  B00006B7DA    769  10.0
# 7894  A3FTRN2V98QBCP  B000062VUO    747  11.0
# 2585  A3FTRN2V98QBCP  B00004SABB    733  12.0
# 35    A3FTRN2V98QBCP  0972683275    726  13.0
# 5756  A3FTRN2V98QBCP  B00005ATMB    708  14.0
# 8771  A3FTRN2V98QBCP  B000067O5G    704  15.0
# 2591  A3FTRN2V98QBCP  B00004SB92    703  16.0
# 8844  A3FTRN2V98QBCP  B000067RC4    692  17.0
# 8310  A3FTRN2V98QBCP  B0000645RH    667  18.0
# 6677  A3FTRN2V98QBCP  B00005NIMJ    628  19.0
# 8936  A3FTRN2V98QBCP  B000067RT6    601  20.0

# %%
print(train_df[train_df['UserID'] == uid])
# Out:
#                UserID      ItemID  Rating
# 37377  A3FTRN2V98QBCP  B00004RFIP     4.0
# 18022  A3FTRN2V98QBCP  B00000JYWQ     5.0
# 35575  A3FTRN2V98QBCP  B00003WGP5     4.0

# %%
## Above Popularity Based approach shows no Personalisation

# %%
## To have some personalisation - use Item based

# %%
item_PM = Recommenders.item_similarity_recommender_py()

# %%
item_PM.create(train_df,'UserID','ItemID')

# %%
item_PM.get_user_items(uid)
# Out:
# ['B00004RFIP', 'B00000JYWQ', 'B00003WGP5']

# %%
def recommend_item(user):
    user_songs = item_PM.get_user_items(user)    
    print("No. of unique items for the user: %d" % len(user_songs))
    all_songs = item_PM.get_all_items_train_data()
    print("no. of unique items in the training set: %d" % len(all_songs))
    cooccurence_matrix = item_PM.construct_cooccurence_matrix(user_songs, all_songs)
    df_recommendations = item_PM.generate_top_recommendations(user, cooccurence_matrix, all_songs, user_songs)
    return df_recommendations

# %%
recommended_items = recommend_item(uid)
# Out:
# No. of unique items for the user: 3
# no. of unique items in the training set: 11796
# Non zero values in cooccurence_matrix :72

# %%
recommended_items
# Out:
#            userId     movieId     score rank
# 0  A3FTRN2V98QBCP  B00000JBRP  0.006410    1
# 1  A3FTRN2V98QBCP  B00004Z5SG  0.006410    2
# 2  A3FTRN2V98QBCP  B00004RG7O  0.006410    3
# 3  A3FTRN2V98QBCP  B00004XREC  0.006289    4
# 4  A3FTRN2V98QBCP  B00000J4A5  0.006173    5
# 5  A3FTRN2V98QBCP  B00000JI4A  0.006173    6
# 6  A3FTRN2V98QBCP  B00005A1KV  0.005747    7
# 7  A3FTRN2V98QBCP  B000066TPO  0.005496    8
# 8  A3FTRN2V98QBCP  B00004UE2J  0.004975    9
# 9  A3FTRN2V98QBCP  B00006HUAS  0.004762   10

# %%
### When we compare the recommended items for the same user, popularity based RS recommends 20 products,where when compared with 
### item based recommendation sys, it gets only top 10 recommendations.

# %%
### Collaborative Filtering

# %%
from scipy import stats
from sklearn.metrics.pairwise import linear_kernel, cosine_similarity
from surprise import Reader, Dataset, SVD, evaluate, KNNBasic

# %%
reader = Reader()
data = Dataset.load_from_df(df[['UserID', 'ItemID', 'Rating']], reader)
data.split(n_folds=5)
evaluate(svd, data, measures=['RMSE', 'MAE'])
# Out:
# C:\Users\Swetha\Anaconda3\lib\site-packages\surprise\evaluate.py:66: UserWarning: The evaluate() method is deprecated. Please use model_selection.cross_validate() instead.
#   'model_selection.cross_validate() instead.', UserWarning)
# C:\Users\Swetha\Anaconda3\lib\site-packages\surprise\dataset.py:193: UserWarning: Using data.split() or using load_from_folds() without using a CV iterator is now deprecated.
#   UserWarning)
# Evaluating RMSE, MAE of algorithm SVD.
#
# ------------
# Fold 1
# RMSE: 1.2911
# MAE:  1.0195
# ------------
# Fold 2
# RMSE: 1.3020
# MAE:  1.0262
# ------------
# Fold 3
# RMSE: 1.3017
# MAE:  1.0251
# ------------
# Fold 4
# RMSE: 1.2848
# MAE:  1.0139
# ------------
# Fold 5
# RMSE: 1.2983
# MAE:  1.0258
# ------------
# ------------
# Mean RMSE: 1.2956
# Mean MAE : 1.0221
# ------------
# ------------
# CaseInsensitiveDefaultDict(list,
#                            {'mae': [1.0194572807581757,
#                              1.026206623076863,
#                              1.025143227117134,
#                              1.0139475878289075,
#                              1.0258396873954028],
#                             'rmse': [1.2911411201424752,
#                              1.3019651089080901,
#                              1.3016709404138072,
#                              1.28482654452442,
#                              1.2982584822199361]})

# %%
from surprise import accuracy
# We'll use the famous SVD algorithm.
algo = SVD()
trainset, testset = train_test_split(data, test_size=.25)
# Train the algorithm on the trainset, and predict ratings for the testset
algo.fit(trainset)
predictions = algo.test(testset)

# Then compute RMSE
accuracy.rmse(predictions)
# Out:
# RMSE: 1.2928
# 1.2928090005490744

# %%
ds[ds['UserID'] == uid]
# Out:
#                  UserID      ItemID  Rating
# 18022    A3FTRN2V98QBCP  B00000JYWQ     5.0
# 35575    A3FTRN2V98QBCP  B00003WGP5     4.0
# 37377    A3FTRN2V98QBCP  B00004RFIP     4.0
# 327214   A3FTRN2V98QBCP  B0000BVV37     4.0
# 545360   A3FTRN2V98QBCP  B00065HLTW     4.0
# 678891   A3FTRN2V98QBCP  B0009Q4PH4     4.0
# 1406961  A3FTRN2V98QBCP  B000UVM0ES     4.0

# %%
algo.predict(uid, 'B00000JYWQ' , 5)
# Out:
# Prediction(uid='A3FTRN2V98QBCP', iid='B00000JYWQ', r_ui=5, est=4.268064398163256, details={'was_impossible': False})

# %%
from surprise.model_selection import GridSearchCV
param_grid = {'n_epochs': [10,20], 'lr_all': [0.001, 0.005],
              'reg_all': [0.6, 0.8]}
gs = GridSearchCV(SVD, param_grid, measures=['rmse', 'mae'], cv=5)

gs.fit(data)

# best RMSE score
print(gs.best_score['rmse'])

# combination of parameters that gave the best RMSE score
print(gs.best_params['rmse'])
# Out:
# 1.3021912443295884
# {'n_epochs': 20, 'lr_all': 0.005, 'reg_all': 0.6}

# %%
best_SVD_algo = gs.best_estimator['rmse']

# %%
best_SVD_algo.fit(trainset)

# %%
pred = best_SVD_algo.predict(uid,'B00000JYWQ',5)

# %%
score=pred.est
print(score)
# Out:
# 4.182052572679787

# %%
### Making Recommendations

# %%
iids = ds['ItemID'].unique()
iids_uid = ds.loc[ds['UserID'] == uid , 'ItemID']
iids_to_predict = np.setdiff1d(iids,iids_uid)

# %%
testset = [[uid,iid,5] for iid in iids_to_predict]
predictions = best_SVD_algo.test(testset)
predictions[0]
# Out:
# Prediction(uid='A3FTRN2V98QBCP', iid='0132793040', r_ui=5, est=4.040179286799432, details={'was_impossible': False})

# %%
predictions
# Out:
# [Prediction(uid='A3FTRN2V98QBCP', iid='0132793040', r_ui=5, est=4.040179286799432, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='0321732944', r_ui=5, est=4.257434617900313, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='0439886341', r_ui=5, est=4.0380265087503755, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='0511189877', r_ui=5, est=4.301470389721395, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='0528881469', r_ui=5, est=3.393588729172877, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='0558835155', r_ui=5, est=4.059025202855743, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='059400232X', r_ui=5, est=4.137776725798517, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='0594012015', r_ui=5, est=3.1849475471181337, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='0594017343', r_ui=5, est=3.9174616154962316, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='0594017580', r_ui=5, est=4.059025202855743, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='0594033896', r_ui=5, est=4.173610953845077, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='0594033926', r_ui=5, est=4.2124976938670216, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='0594033934', r_ui=5, est=4.2035386086431155, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='0594202442', r_ui=5, est=4.09180896995354, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='0594287995', r_ui=5, est=4.059025202855743, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='0594296420', r_ui=5, est=4.154694204379392, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='0594450209', r_ui=5, est=4.205298965834271, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='0594450705', r_ui=5, est=4.190069608278139, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='0594451647', r_ui=5, est=4.2879526010876, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='0594477670', r_ui=5, est=4.113597963744483, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='0594478162', r_ui=5, est=4.059025202855743, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='0594481813', r_ui=5, est=4.170554860877627, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='0594481902', r_ui=5, est=4.180109692730053, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='0594482127', r_ui=5, est=4.059025202855743, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='0594511488', r_ui=5, est=4.245728885619836, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='0594514681', r_ui=5, est=4.257651296830079, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='0594514789', r_ui=5, est=4.059025202855743, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='0594549507', r_ui=5, est=4.016135151804881, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='0594549558', r_ui=5, est=4.210980547274278, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='0743610431', r_ui=5, est=4.131295158231803, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='0777700018', r_ui=5, est=4.290876937443479, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='0840017677', r_ui=5, est=4.053670373834895, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='0879393742', r_ui=5, est=4.025798097134221, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='089933623X', r_ui=5, est=3.868321133834263, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='0899336795', r_ui=5, est=2.8667764449961015, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='094339676X', r_ui=5, est=4.059025202855743, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='0970407998', r_ui=5, est=4.137799051816869, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='0970408005', r_ui=5, est=4.002486743035103, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='0972683275', r_ui=5, est=4.3197846806275955, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='0977703037', r_ui=5, est=4.059025202855743, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='0978770382', r_ui=5, est=4.062202541242441, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='0979526191', r_ui=5, est=3.9152494586013122, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='0983947600', r_ui=5, est=3.950916271888705, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid
details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='998559987X', r_ui=5, est=4.067299056082167, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='9985600266', r_ui=5, est=3.9482560535597417, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='9985600363', r_ui=5, est=4.059025202855743, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='9985602560', r_ui=5, est=3.3315500749411724, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='9985603877', r_ui=5, est=4.291685133660196, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='9985605810', r_ui=5, est=3.8076720904367396, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='9985606094', r_ui=5, est=4.176731754144295, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='9985606183', r_ui=5, est=4.142208692658618, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='9985606256', r_ui=5, est=3.750428042495925, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='9985607600', r_ui=5, est=4.193949586845042, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='9985609034', r_ui=5, est=4.3557982416084124, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='9985610016', r_ui=5, est=4.0014313816697875, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='9985614151', r_ui=5, est=3.8232467500633662, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='9985614682', r_ui=5, est=3.9221621883305806, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='9985614690', r_ui=5, est=3.548179416389164, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='9985615220', r_ui=5, est=3.9819312855044235, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='9985615255', r_ui=5, est=4.145038322157658, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='9985616006', r_ui=5, est=4.239069751453174, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='9985616324', r_ui=5, est=4.059025202855743, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='9985616669', r_ui=5, est=3.954870026901994, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='9985617827', r_ui=5, est=4.059025202855743, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='9985622456', r_ui=5, est=4.196313414858049, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='9985622650', r_ui=5, est=3.8350764818355896, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='9985622812', r_ui=5, est=4.072491437440326, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='9985628705', r_ui=5, est=4.203118526142461, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='9985629515', r_ui=5, est=3.763822619869588, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='9985629779', r_ui=5, est=3.7665700206445294, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='9985630734', r_ui=5, est=4.10407225288649, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='9985631021', r_ui=5, est=4.145001317421765, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='9985631706', r_ui=5, est=3.9669765456967374, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='9985631722', r_ui=5, est=4.196916906095419, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='9985632354', r_ui=5, est=4.06927344006772, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='9985632419', r_ui=5, est=4.088031780619637, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='9985632931', r_ui=5, est=4.059025202855743, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='9985634551', r_ui=5, est=4.1186774198985905, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='9985634780', r_ui=5, est=4.059025202855743, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='9985635493', r_ui=5, est=4.187495407003813, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='9985635930', r_ui=5, est=4.059025202855743, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='9985636058', r_ui=5, est=4.1257514402953825, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='9985636104', r_ui=5, est=4.1436030928333825, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='9985636112', r_ui=5, est=4.059025202855743, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='9985637046', r_ui=5, est=4.059025202855743, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='9985637100', r_ui=5, est=4.059025202855743, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='9985644069', r_ui=5, est=3.86287571422109, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='9985648471', r_ui=5, est=4.059471417424738, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='9985654056', r_ui=5, est=3.8307013950256703, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='9985665899', r_ui=5, est=4.283823377650279, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='998566891X', r_ui=5, est=4.130079892025929, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='998566941X', r_ui=5, est=4.213219532417035, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='998566969X', r_ui=5, est=4.059025202855743, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='9985669819', r_ui=5, est=4.098400044145624, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='9985669886', r_ui=5, est=4.14019625820917, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='9985671678', r_ui=5, est=4.124170355190565, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='998567197X', r_ui=5, est=4.09380108261368, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='9985672887', r_ui=5, est=4.077763103459771, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='9985672917', r_ui=5, est=3.7990588295548147, details={'was_impossible': False}),
#  Prediction(uid='A3FTRN2V98QBCP', iid='9985673379', r_ui=5, est=4.315899654066662, details={'was_impossible': False}),
#  ...]

# %%
# Here each prediction is a object, hence we need to convert it to aparse matrix, then pick recommendations

# %%
pred_rating = np.array[[pred.est for pred in predictions]]
item_max = pred_rating.argpartition(5)
iids = iids_to_predict(item_max)
